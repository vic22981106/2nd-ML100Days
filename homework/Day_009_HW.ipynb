# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# generate x, y data
x = np.random.randint(0,50,1000)
y = -2*x + np.random.normal(0,10,1000)

# calculate the correlation coefficient
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94297613],
#        [-0.94297613,  1.        ]])

# %%
# plot the scattering plot
plt.scatter(x, y)
